# %%
#to check whethe the number is palidrome number
n = int(input("enter a number"))
m=n
sum=0
while(m>0):
  rem=m%10
  sum=sum*10+rem
  m=m//10
  if(sum==n):
    print(n,"is a palindrome number")
  else:
    print(n,"is not a palidrome number")
# Out:
# enter a number5
# 5 is a palindrome number
